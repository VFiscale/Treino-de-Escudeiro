# %% [markdown]
# <a href="https://colab.research.google.com/github/VFiscale/Treino-de-Escudeiro/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Preparação da API

# %%
import pandas as pd

# %%
# !pip install xlrd

# %% [markdown]
# # **Análise das Eleições Presidênciais de 2022**
#
# **Objetivo:** analisar as bases de dados do TSE
# referêntes aos resultados das eleições presidênciais e dos doadores/financiadores de cada campanha, para descobrir os dez (10) maiores financiadores (bilionários) dos candidatos à governador, presidente e senador. Usar como base, as seguintes fontes de dados:
# - https://dadosabertos.tse.jus.br/dataset/dadosabertos-tse-jus-br-dataset-prestacao-de-contas-eleitorais-2022;
#
# - https://www.kaggle.com/datasets/roysouravcu/forbes-billionaires-of-2021.
#
#
# ---
#
#
# **PASSO A PASSO:**
# 1. Baixar as bases de dados;
# 2. Importar os dados e nomear as tabelas;
# 3. Juntar os dados;
# 4. Encontrar os resultados do objetivo acima.
# 5. Disponibilizar o projeto no Github; o resultado final, deve ser no seguinte formato: `Nome do Bilionário|valor doação|candidato|cargo|estado`

# %% [markdown]
# # **1**

# %%
#Importando a tabela Billionaires.xls
df_1= pd.read_csv('/content/Billionaire.csv', sep=',')

# %%
display(df_1)
# Out:
#                           Name NetWorth        Country         Source  Rank  \
# 0                   Jeff Bezos   $177 B  United States         Amazon     1
# 1                    Elon Musk   $151 B  United States  Tesla, SpaceX     2
# 2     Bernard Arnault & family   $150 B         France           LVMH     3
# 3                   Bill Gates   $124 B  United States      Microsoft     4
# 4              Mark Zuckerberg    $97 B  United States       Facebook     5
# ...                        ...      ...            ...            ...   ...
# 2750         Daniel Yong Zhang     $1 B          China     e-commerce  2674
# 2751             Zhang Yuqiang     $1 B          China     Fiberglass  2674
# 2752             Zhao Meiguang     $1 B          China    gold mining  2674
# 2753            Zhong Naixiong     $1 B          China   conglomerate  2674
# 2754           Zhou Wei family     $1 B          China       Software  2674
#
#        Age          Industry
# ...

# %%
url = 'https://cdn.tse.jus.br/estatistica/sead/odsele/prestacao_contas/prestacao_de_contas_eleitorais_orgaos_partidarios_2022.zip'
# Out:
#      <input type="file" id="files-622365b6-8702-45b6-a4dd-9335b02b7541" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-622365b6-8702-45b6-a4dd-9335b02b7541">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Out:
#      <input type="file" id="files-b4701d8e-b141-464e-a67c-03f026b8aa18" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b4701d8e-b141-464e-a67c-03f026b8aa18">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # 2

# %%
#Obtendo nome da tabela Billionaire.xls carregada como 'uploaded' e criando uma chave para interagir com a mesma
Billionaire = next(iter(uploaded))
bilionarios = 'bilionarios.xls'

#Salvando a tabela no sistema como 'bilionarios' em binário ('wb') e escrevendo no arquivo o conteúdo da tabela 'uploaded'
with open(bilionarios, 'wb') as f:
  f.write(uploaded[Billionaire])

# %%
#Obtendo nome da tabela E1TBr2022.csv carregada como 'uploaded1' e criando uma chave para interagir com a mesma
Historico_Totalizacao_Presidente_BR_1T_2022 = next(iter(uploaded1))
turno_1 = 'turno_1.csv'

#Salvando a tabela no sistema como 'turno_1' em binário ('wb') e escrevendo no arquivo o conteúdo da tabela 'uploaded1'
with open(turno_1, 'wb') as f:
  f.write(uploaded1[Historico_Totalizacao_Presidente_BR_1T_2022])

# %%
#Obtendo nome da tabela E2TBr2022.csv carregada como 'uploaded2' e criando uma chave para interagir com a mesma
Historico_Totalizacao_Presidente_BR_2T_2022 = next(iter(uploaded2))
turno_2 = 'turno_2.csv'

#Salvando a tabela no sistema como 'turno_2' em binário ('wb') e escrevendo no arquivo o conteúdo da tabela 'uploaded2'
with open(turno_2, 'wb') as f:
  f.write(uploaded2[Historico_Totalizacao_Presidente_BR_2T_2022])
